# %% [markdown]
# ### To test your implementation, copy-paste these cells at THE END of your own .ipynb file. Make sure that your functions meet the return type specified, or else your tests won't pass!
#
# ### NOTE: These test cases aren't exhaustive!

# %%
'''TEST 1'''

starting_coordinates = (2,0)

coordinates_of_first_pit = (0,2)
coordinates_of_second_pit = (1,2)
coordinates_of_third_pit = (1,3)

coordinates_of_gold = (0,3)

coordinate_labels = dict.fromkeys(possible_coordinates , '.')
coordinate_labels[coordinates_of_gold] = 'G'
coordinate_labels[coordinates_of_first_pit] = 'P'
coordinate_labels[coordinates_of_second_pit] = 'P'
coordinate_labels[coordinates_of_third_pit] = 'P'
coordinate_labels[starting_coordinates] = 'S'

relfex_agent_result = simpleReflexAgent(coordinate_labels)
print("\n\n==============================================")
if (relfex_agent_result == "unsolvable"):
    print("Test 1.1 Passed! :D")
    print("==============================================")
else:
    print("Test 1.1 Failed! :(")
    print("----Expected Output:" , "unsolvable")
    print("----Actual Output:", relfex_agent_result)
    print("==============================================")

# =================================================================================
model_based_agent_result = modelBasedAgent(coordinate_labels , cash_available)
print("\n\n==============================================")
if(len(model_based_agent_result) != 2):
    print("Test 1.2 failed! :(")
    print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"unsolvable\".")
    print("\n----Got the output:" , model_based_agent_result) 
    print("==============================================")

elif (len(model_based_agent_result) == 2):
    agent_model = model_based_agent_result[0]
    return_string = model_based_agent_result[1]
    if (return_string == "unsolvable"):
        print("Test 2.2 Passed! :D")
        print("==============================================")

    else:
        print("Test 2.2 failed! :(")
        print("----Expected Output:" , "unsolvable")
        print("----Actual Output:" , model_based_agent_result) 
# =================================================================================

# %%
'''TEST 2'''

starting_coordinates = (1,0)

coordinates_of_first_pit = (2,2)
coordinates_of_second_pit = (2,3)
coordinates_of_third_pit = (3,2)

coordinates_of_gold = (3,3)

coordinate_labels = dict.fromkeys(possible_coordinates , '.')
coordinate_labels[coordinates_of_gold] = 'G'
coordinate_labels[coordinates_of_first_pit] = 'P'
coordinate_labels[coordinates_of_second_pit] = 'P'
coordinate_labels[coordinates_of_third_pit] = 'P'
coordinate_labels[starting_coordinates] = 'S'


relfex_agent_result = simpleReflexAgent(coordinate_labels)
print("\n\n==============================================")
if (relfex_agent_result == "unsolvable"):
    # enablePrint()
    print("Test 2.1 Passed! :D")
    print("==============================================")
else:
    # enablePrint()
    print("Test 2.1 Failed! :(")
    print("----Expected Output:" , "unsolvable")
    print("----Actual Output:", relfex_agent_result)
    print("==============================================")

# =================================================================================
model_based_agent_result = modelBasedAgent(coordinate_labels , cash_available)
print("\n\n==============================================")
if(len(model_based_agent_result) != 2):
    print("Test 1.2 failed! :(")
    print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"unsolvable\".")
    print("\n----Got the output:" , model_based_agent_result) 
    print("==============================================")

elif (len(model_based_agent_result) == 2):
    agent_model = model_based_agent_result[0]
    return_string = model_based_agent_result[1]
    if (return_string == "unsolvable"):
        print("Test 2.2 Passed! :D")
        print("==============================================")

    else:
        print("Test 2.2 failed! :(")
        print("----Expected Output:" , "unsolvable")
        print("----Actual Output:" , model_based_agent_result) 
# =================================================================================

# %%
'''TEST 3'''

starting_coordinates = (2,0)

coordinates_of_first_pit = (1,0)
coordinates_of_second_pit = (2,1)
coordinates_of_third_pit = (3,0)

coordinates_of_gold = (0,3)

coordinate_labels = dict.fromkeys(possible_coordinates , '.')
coordinate_labels[coordinates_of_gold] = 'G'
coordinate_labels[coordinates_of_first_pit] = 'P'
coordinate_labels[coordinates_of_second_pit] = 'P'
coordinate_labels[coordinates_of_third_pit] = 'P'
coordinate_labels[starting_coordinates] = 'S'

relfex_agent_result = simpleReflexAgent(coordinate_labels)
print("\n\n==============================================")
if (relfex_agent_result == "unsolvable"):
    # enablePrint()
    print("Test 3.1 Passed! :D")
    print("==============================================")
else:
    # enablePrint()
    print("Test 3.1 Failed! :(")
    print("----Expected Output:" , "unsolvable")
    print("----Actual Output:", relfex_agent_result)
    print("==============================================")

# =================================================================================
model_based_agent_result = modelBasedAgent(coordinate_labels , cash_available)
print("\n\n==============================================")
if(len(model_based_agent_result) != 2):
    print("Test 1.2 failed! :(")
    print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"unsolvable\".")
    print("\n----Got the output:" , model_based_agent_result) 
    print("==============================================")

elif (len(model_based_agent_result) == 2):
    agent_model = model_based_agent_result[0]
    return_string = model_based_agent_result[1]
    if (return_string == "unsolvable"):
        print("Test 2.2 Passed! :D")
        print("==============================================")

    else:
        print("Test 2.2 failed! :(")
        print("----Expected Output:" , "unsolvable")
        print("----Actual Output:" , model_based_agent_result) 
# =================================================================================

# %%
'''TEST 4'''

starting_coordinates = (2,2)

coordinates_of_first_pit = (0,1)
coordinates_of_second_pit = (1,2)
coordinates_of_third_pit = (2,1)

coordinates_of_gold = (2,0)

coordinate_labels = dict.fromkeys(possible_coordinates , '.')
coordinate_labels[coordinates_of_gold] = 'G'
coordinate_labels[coordinates_of_first_pit] = 'P'
coordinate_labels[coordinates_of_second_pit] = 'P'
coordinate_labels[coordinates_of_third_pit] = 'P'
coordinate_labels[starting_coordinates] = 'S'

relfex_agent_result = simpleReflexAgent(coordinate_labels)
print("\n\n==============================================")
if (relfex_agent_result == "Gold Found!"):
    # enablePrint()
    print("Test 4.1 Passed! :D")
    print("==============================================")
else:
    # enablePrint()
    print("Test 4.1 Failed! :(")
    print("----Expected Output:" , "Gold Found!")
    print("----Actual Output:", relfex_agent_result)
    print("==============================================")

model_based_agent_result = modelBasedAgent(coordinate_labels , cash_available)
print("\n\n==============================================")
if(len(model_based_agent_result) != 2):
    print("Test 4.2 failed! :(")
    print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"Gold Found! x dollars left in the bank too!\", and x >= 2000.")
    print("\n----Got the output:" , model_based_agent_result) 
    print("==============================================")

elif (len(model_based_agent_result) == 2):
    agent_model = model_based_agent_result[0]
    return_string = model_based_agent_result[1]
    if (return_string[0:11] == "Gold Found!"):
        x = 0
        try:
            x = int(return_string[12:16])
        except:
            pass
        
        num_of_pits_discovered_by_agent = 0
        for x_y in agent_model.keys():
            if agent_model[x_y] == "P":
                num_of_pits_discovered_by_agent += 1

        expected_x = 5000 - (num_of_pits_discovered_by_agent * 1000)
        output_x = x

        if (output_x == expected_x):
            print("Test 4.2 Passed! :D")
            print("==============================================")

        else:
            print("Test 4.2 failed! :(")
            print("----Expected Output: Gold Found!" , expected_x , "dollars left in the bank too!")
            print("----Actual Output:" , return_string) 
            print("==============================================")
        
    else:
        print("Test 4.2 failed! :(")
        print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"Gold Found! x dollars left in the bank too!\", and x >= 2000.")
        print("----Got" , model_based_agent_result , "in the output")  
        print("==============================================")

# %%
'''TEST 5'''

starting_coordinates = (2,2)

coordinates_of_first_pit = (0,1)
coordinates_of_second_pit = (1,2)
coordinates_of_third_pit = (2,1)

coordinates_of_gold = (1,1)

coordinate_labels = dict.fromkeys(possible_coordinates , '.')
coordinate_labels[coordinates_of_gold] = 'G'
coordinate_labels[coordinates_of_first_pit] = 'P'
coordinate_labels[coordinates_of_second_pit] = 'P'
coordinate_labels[coordinates_of_third_pit] = 'P'
coordinate_labels[starting_coordinates] = 'S'

relfex_agent_result = simpleReflexAgent(coordinate_labels)
print("\n\n==============================================")
if (relfex_agent_result == "Gold Found!"):
    print("Test 5.1 Passed! :D")
    print("==============================================")
else:
    print("Test 5.1 Failed! :(")
    print("----Expected Output:" , "Gold Found!")
    print("----Actual Output:", relfex_agent_result)
    print("==============================================")

model_based_agent_result = modelBasedAgent(coordinate_labels , cash_available)
print("\n\n==============================================")
if(len(model_based_agent_result) != 2):
    print("Test 5.2 failed! :(")
    print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"Gold Found! x dollars left in the bank too!\", and x >= 2000.")
    print("\n----Got the output:" , model_based_agent_result) 
    print("==============================================")

elif (len(model_based_agent_result) == 2):
    agent_model = model_based_agent_result[0]
    return_string = model_based_agent_result[1]
    if (return_string[0:11] == "Gold Found!"):
        x = 0
        try:
            x = int(return_string[12:16])
        except:
            pass
        
        num_of_pits_discovered_by_agent = 0
        for x_y in agent_model.keys():
            if agent_model[x_y] == "P":
                num_of_pits_discovered_by_agent += 1

        expected_x = 5000 - (num_of_pits_discovered_by_agent * 1000)
        output_x = x

        if (output_x == expected_x):
            print("Test 5.2 Passed! :D")
            print("==============================================")

        else:
            print("Test 5.2 failed! :(")
            print("----Expected Output: Gold Found!" , expected_x , "dollars left in the bank too!")
            print("----Actual Output:" , return_string) 
            print("==============================================")
        
    else:
        print("Test 5.2 failed! :(")
        print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"Gold Found! x dollars left in the bank too!\", and x >= 2000.")
        print("\n----Got" , model_based_agent_result , "in the output")  
        print("==============================================")

# %%
'''TEST 6'''

starting_coordinates = (2,1)

coordinates_of_first_pit = (1,2)
coordinates_of_second_pit = (2,0)
coordinates_of_third_pit = (3,2)

coordinates_of_gold = (3,3)

coordinate_labels = dict.fromkeys(possible_coordinates , '.')
coordinate_labels[coordinates_of_gold] = 'G'
coordinate_labels[coordinates_of_first_pit] = 'P'
coordinate_labels[coordinates_of_second_pit] = 'P'
coordinate_labels[coordinates_of_third_pit] = 'P'
coordinate_labels[starting_coordinates] = 'S'

relfex_agent_result = simpleReflexAgent(coordinate_labels)
print("\n\n==============================================")
if (relfex_agent_result == "Gold Found!"):
    print("Test 6.1 Passed! :D")
    print("==============================================")
else:
    print("Test 6.1 Failed! :(")
    print("----Expected Output:" , "Gold Found!")
    print("----Actual Output:", relfex_agent_result)
    print("==============================================")

model_based_agent_result = modelBasedAgent(coordinate_labels , cash_available)
print("\n\n==============================================")
if(len(model_based_agent_result) != 2):
    print("Test 6.2 failed! :(")
    print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"Gold Found! x dollars left in the bank too!\", and x >= 2000.")
    print("\n----Got the output:" , model_based_agent_result) 
    print("==============================================")

elif (len(model_based_agent_result) == 2):
    agent_model = model_based_agent_result[0]
    return_string = model_based_agent_result[1]
    if (return_string[0:11] == "Gold Found!"):
        x = 0
        try:
            x = int(return_string[12:16])
        except:
            pass
        
        num_of_pits_discovered_by_agent = 0
        for x_y in agent_model.keys():
            if agent_model[x_y] == "P":
                num_of_pits_discovered_by_agent += 1

        expected_x = 5000 - (num_of_pits_discovered_by_agent * 1000)
        output_x = x

        if (output_x == expected_x):
            print("Test 6.2 Passed! :D")
            print("==============================================")

        else:
            print("Test 6.2 failed! :(")
            print("----Expected Output: Gold Found!" , expected_x , "dollars left in the bank too!")
            print("----Actual Output:" , return_string) 
            print("==============================================")
        
    else:
        print("Test 6.2 failed! :(")
        print("----Expected a tuple of the form (agent_model , return_string), where: \n      agent_model is the model that the agent has generated for itself.\n      return_string is \"Gold Found! x dollars left in the bank too!\", and x >= 2000.")
        print("\n----Got" , model_based_agent_result , "in the output")  
        print("==============================================")
